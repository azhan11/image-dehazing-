# %%
import deeplake
ds = deeplake.load("hub://activeloop/reside")
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\deeplake\util\check_latest_version.py:32: UserWarning: A newer version of deeplake (4.0.3) is available. It's recommended that you update to the latest version using `pip install -U deeplake`.
#   warnings.warn(
# |
# Opening dataset in read-only mode as you don't have write permissions.
# -
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/reside
# hub://activeloop/reside loaded successfully.

# %%
dataloader = ds.pytorch(num_workers=0, batch_size=1, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dataloader = ds.pytorch(num_workers=0, batch_size=1, shuffle=True)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\deeplake\core\dataset\dataset.py:2158, in Dataset.pytorch(self, transform, tensors, num_workers, batch_size, drop_last, collate_fn, pin_memory, shuffle, buffer_size, use_local_cache, progressbar, return_index, pad_tensors, transform_kwargs, decode_method, cache_size, *args, **kwargs)
#    2155 if transform and transform_kwargs:
#    2156     transform = partial(transform, **transform_kwargs)
# -> 2158 dataloader = to_pytorch(
#    2159     self,
#    2160     *args,
#    2161     transform=transform,
#    2162     tensors=tensors,
#    2163     num_workers=num_workers,
#    2164     batch_size=batch_size,
#    2165     drop_last=drop_last,
# ...

# %%
next(iter(dataloader))
# Out:
# IterableOrderedDict([('images',
#                       tensor([[[161, 161, 161,  ..., 176, 176, 176],
#                                [161, 161, 161,  ..., 176, 176, 176],
#                                [161, 161, 161,  ..., 176, 176, 176],
#                                ...,
#                                [203, 203, 203,  ..., 170, 170, 170],
#                                [203, 203, 203,  ..., 170, 170, 170],
#                                [203, 203, 203,  ..., 170, 170, 170]]], dtype=torch.uint8)),
#                      ('labels', tensor([[1]])),
#                      ('index', tensor([[9650]], dtype=torch.int32))])

# %%
import deeplake 
import os 

os.environ['ACTIVELOOP_TOKEN'] = "eyJhbGciOiJub25lIiwidHlwIjoiSldUIn0.eyJpZCI6ImttbGp0IiwiYXBpX2tleSI6Ik9XSTdxalZELVFQVDRxdS1JXzB5d2h2SXhfVWplMmc1OTBDRmNLQ1g2YWZiUiJ9."

images_directory = 'Datasets/RESIDE-6K/train' 
deeplake_path = 'hub://kmljt/RESIDE-6K' 

ds = deeplake.ingest_yolo(images_directory, deeplake_path, allow_no_annotation=True)
# Out:
# Annotation was not found for hazy/2406.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for GT/918.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for hazy/1998.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for hazy/2237.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for GT/2905.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for GT/692.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for GT/1149.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for hazy/5567.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for GT/1416.jpg. Empty annotation data will be appended for this image.
# Annotation was not found for hazy/5235.jpg. Empty annotation data will be appended for this image.
# ...

# %%
from PIL import Image

img = Image.open('Datasets/RESIDE-6K/train/GT/1.jpg').convert('RGB')

# %%
from torchvision import transforms

transforms.ToTensor()(img)
# Out:
# tensor([[[0.9059, 0.8902, 0.8863,  ..., 0.8510, 0.8510, 0.8510],
#          [0.8980, 0.8902, 0.8824,  ..., 0.8510, 0.8510, 0.8510],
#          [0.8941, 0.8902, 0.8784,  ..., 0.8510, 0.8510, 0.8510],
#          ...,
#          [0.2471, 0.2314, 0.2392,  ..., 0.2588, 0.3647, 0.3961],
#          [0.2471, 0.2353, 0.2549,  ..., 0.2196, 0.3451, 0.3882],
#          [0.2431, 0.2314, 0.2549,  ..., 0.1843, 0.3333, 0.3765]],
#
#         [[0.9059, 0.8980, 0.9020,  ..., 0.8667, 0.8667, 0.8667],
#          [0.8980, 0.8980, 0.8980,  ..., 0.8667, 0.8667, 0.8667],
#          [0.8941, 0.8980, 0.8941,  ..., 0.8667, 0.8667, 0.8667],
#          ...,
#          [0.2471, 0.2353, 0.2471,  ..., 0.1451, 0.1373, 0.1216],
#          [0.2471, 0.2392, 0.2627,  ..., 0.1216, 0.1451, 0.1373],
#          [0.2431, 0.2353, 0.2627,  ..., 0.1059, 0.1373, 0.1333]],
#
#         [[0.9059, 0.8941, 0.8980,  ..., 0.8784, 0.8784, 0.8784],
#          [0.8980, 0.8941, 0.8941,  ..., 0.8784, 0.8784, 0.8784],
# ...

# %%
import os

os.listdir('Datasets/RESIDE-6K/train/GT')
# Out:
# ['1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '1000.jpg',
#  '1001.jpg',
#  '1002.jpg',
#  '1003.jpg',
#  '1004.jpg',
#  '1005.jpg',
#  '1006.jpg',
#  '1007.jpg',
#  '1008.jpg',
#  '1009.jpg',
#  '101.jpg',
#  '1010.jpg',
#  '1011.jpg',
#  '1012.jpg',
#  '1013.jpg',
#  '1014.jpg',
#  '1015.jpg',
#  '1016.jpg',
#  '1017.jpg',
#  '1018.jpg',
#  '1019.jpg',
#  '102.jpg',
#  '1020.jpg',
#  '1021.jpg',
#  '1022.jpg',
#  '1023.jpg',
#  '1024.jpg',
#  '1025.jpg',
#  '1026.jpg',
#  '1027.jpg',
#  '1028.jpg',
#  '1029.jpg',
#  '103.jpg',
#  '1030.jpg',
#  '1031.jpg',
#  '1032.jpg',
#  '1033.jpg',
#  '1034.jpg',
#  '1035.jpg',
#  '1036.jpg',
#  '1037.jpg',
#  '1038.jpg',
#  '1039.jpg',
#  '104.jpg',
#  '1040.jpg',
#  '1041.jpg',
#  '1042.jpg',
#  '1043.jpg',
#  '1044.jpg',
#  '1045.jpg',
#  '1046.jpg',
#  '1047.jpg',
#  '1048.jpg',
#  '1049.jpg',
#  '105.jpg',
#  '1050.jpg',
#  '1051.jpg',
#  '1052.jpg',
#  '1053.jpg',
#  '1054.jpg',
#  '1055.jpg',
#  '1056.jpg',
#  '1057.jpg',
#  '1058.jpg',
# ...

# %%
os.listdir('Datasets/RESIDE-6K/train/hazy')
# Out:
# ['1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '1000.jpg',
#  '1001.jpg',
#  '1002.jpg',
#  '1003.jpg',
#  '1004.jpg',
#  '1005.jpg',
#  '1006.jpg',
#  '1007.jpg',
#  '1008.jpg',
#  '1009.jpg',
#  '101.jpg',
#  '1010.jpg',
#  '1011.jpg',
#  '1012.jpg',
#  '1013.jpg',
#  '1014.jpg',
#  '1015.jpg',
#  '1016.jpg',
#  '1017.jpg',
#  '1018.jpg',
#  '1019.jpg',
#  '102.jpg',
#  '1020.jpg',
#  '1021.jpg',
#  '1022.jpg',
#  '1023.jpg',
#  '1024.jpg',
#  '1025.jpg',
#  '1026.jpg',
#  '1027.jpg',
#  '1028.jpg',
#  '1029.jpg',
#  '103.jpg',
#  '1030.jpg',
#  '1031.jpg',
#  '1032.jpg',
#  '1033.jpg',
#  '1034.jpg',
#  '1035.jpg',
#  '1036.jpg',
#  '1037.jpg',
#  '1038.jpg',
#  '1039.jpg',
#  '104.jpg',
#  '1040.jpg',
#  '1041.jpg',
#  '1042.jpg',
#  '1043.jpg',
#  '1044.jpg',
#  '1045.jpg',
#  '1046.jpg',
#  '1047.jpg',
#  '1048.jpg',
#  '1049.jpg',
#  '105.jpg',
#  '1050.jpg',
#  '1051.jpg',
#  '1052.jpg',
#  '1053.jpg',
#  '1054.jpg',
#  '1055.jpg',
#  '1056.jpg',
#  '1057.jpg',
#  '1058.jpg',
# ...

# %%
image1 = Image.open('Datasets/RESIDE-6K/train/GT/1000.jpg').convert('RGB')
image2 = Image.open('Datasets/RESIDE-6K/train/hazy/1000.jpg')

# Calculate the width and height for the new image
new_width = image1.width + image2.width
new_height = max(image1.height, image2.height)

# Create a new blank image with white background
new_image = Image.new("RGB", (new_width, new_height), "white")

# Paste the first image on the left side
new_image.paste(image1, (0, 0))

# Paste the second image on the right side
new_image.paste(image2, (image1.width, 0))

new_image
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>
